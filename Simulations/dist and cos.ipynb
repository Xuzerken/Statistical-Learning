# %%
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pts = []
for i in range(30):
    pts.append(np.random.random(100)-0.5)
pts = np.array(pts)
pts
# Out:
# array([[ 0.09567803,  0.26377876,  0.02753764, ..., -0.20088155,
#          0.03816353,  0.0323655 ],
#        [ 0.22273422, -0.14821052, -0.33991675, ...,  0.492818  ,
#         -0.49769335,  0.39973811],
#        [-0.18644311,  0.46844672, -0.18460496, ..., -0.11369096,
#         -0.18670349,  0.01791614],
#        ...,
#        [ 0.45871172, -0.05086417,  0.09520843, ...,  0.44543339,
#         -0.396161  ,  0.15082873],
#        [ 0.44045757, -0.33831013,  0.04866448, ...,  0.08615735,
#         -0.22552432, -0.22839269],
#        [-0.1230487 ,  0.13565208, -0.42962878, ..., -0.249208  ,
#          0.22379894,  0.13932634]])

# %%
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform
distA = pdist(pts,metric='euclidean')
distB = squareform(distA)

# %%
print(distA.var())
print(distA.mean())
# Out:
# 0.050208489268834706
# 4.065907285289468

# %%
plt.hist(distA)
plt.grid()
plt.savefig("images/distance/hist.png")

# %%
sns.violinplot(distA)
plt.grid()
plt.savefig("images/distance/violin.png")

# %%
plt.figure(figsize=(10, 10))
hm = sns.heatmap(distB,cbar=True,cmap="GnBu",annot=False,square=True,fmt='.2f',annot_kws={'size': 15})
plt.savefig("images/distance/hm.png")

# %%
cosA = 1- pdist(pts,metric='cosine')
cosB = squareform(cosA)

# %%
plt.hist(cosA)
plt.grid()
plt.savefig("images/cos/hist.png")

# %%
sns.violinplot(cosA)
plt.grid()
plt.savefig("images/cos/violin.png")

# %%
plt.figure(figsize=(10, 10))
hm = sns.heatmap(cosB,cbar=True,cmap="GnBu",annot=False,square=True,fmt='.2f',annot_kws={'size': 15})
plt.savefig("images/cos/hm.png")
