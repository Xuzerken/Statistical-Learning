# %%
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pts = []
for i in range(30):
    pts.append(np.random.random(100)-0.5)
pts = np.array(pts)
pts
# Out:
# array([[-3.63231774e-01, -4.25247762e-01, -3.56129285e-01, ...,
#          2.44076387e-01, -4.38707423e-01,  4.63501042e-01],
#        [ 3.65777731e-01,  2.40674085e-01,  2.50411702e-01, ...,
#         -4.52501483e-01,  2.19082260e-01, -3.15196245e-01],
#        [-1.79710327e-01, -4.85087529e-01,  1.49180646e-01, ...,
#         -5.00561545e-02, -4.08824384e-01,  2.60219272e-01],
#        ...,
#        [ 4.67890903e-02, -3.45109866e-01, -3.60304230e-01, ...,
#         -3.87838430e-01, -2.58235084e-01,  1.93453643e-02],
#        [-4.06398007e-01,  4.36905236e-01,  4.72382109e-01, ...,
#          4.52351778e-01, -3.06665449e-01, -4.07496565e-04],
#        [ 1.11510917e-02, -1.77628831e-01, -2.59205400e-01, ...,
#          1.79412381e-01,  4.64184752e-01,  6.66458005e-02]])

# %%
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform
distA = pdist(pts,metric='euclidean')
distB = squareform(distA)

# %%
print(distA.var())
print(distA.mean())
# Out:
# 0.05770902130847296
# 4.064271806438278

# %%
plt.hist(distA)
plt.grid()
plt.savefig("images/distance/hist.png")

# %%
sns.violinplot(distA)
plt.grid()
plt.savefig("images/distance/violin.png")

# %%
plt.figure(figsize=(10, 10))
hm = sns.heatmap(distB,cbar=True,cmap="jet",annot=False,square=True,fmt='.2f',annot_kws={'size': 15})
plt.savefig("images/distance/hm.png")

# %%
cosA = 1- pdist(pts,metric='cosine')
cosB = squareform(cosA)

# %%
plt.hist(cosA)
plt.grid()
plt.savefig("images/cos/hist.png")

# %%
sns.violinplot(cosA)
plt.grid()
plt.savefig("images/cos/violin.png")

# %%
plt.figure(figsize=(10, 10))
hm = sns.heatmap(cosB,cbar=True,cmap="jet",annot=False,square=True,fmt='.2f',annot_kws={'size': 15})
plt.savefig("images/cos/hm.png")
